# %% [markdown]
# # install packages

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\info\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (2.28.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\info\appdata\local\programs\python\python310\lib\site-packages (from requests) (2022.6.15)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\info\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
import requests
from random import randint
from time import sleep
import os
import pandas as pd
import json
import re
from io import StringIO

# %% [markdown]
# # [OLD] test code

# %%
# url = ''
# url2 = 'https://www.walletexplorer.com/wallet/HelixMixer/addresses?page=2'

# %%
# result = requests.get(url)

# %%
# doc = BeautifulSoup(result.text, "html.parser")
# print(doc.prettify())

# %%
# addresses = doc.find_all(text=re.compile("^(bc1|[13])[a-zA-HJ-NP-Z0-9]{25,39}$") )
# addresses

# %%
# os.listdir()

# %%
# print(dir_save)

# %% [markdown]
# # DEFINE: iterative scaping of websites for wallets of interest

# %% [markdown]
# ## set wallets of interest (mixers)

# %%
mixerList = StringIO('''we-link,mixer
https://www.walletexplorer.com/wallet/HelixMixer,helix
https://www.walletexplorer.com/wallet/HelixMixer-old,helix
https://www.walletexplorer.com/wallet/HelixMixer-old2,helix
https://www.walletexplorer.com/wallet/HelixMixer-old3,helix
https://www.walletexplorer.com/wallet/HelixMixer-old4,helix
https://www.walletexplorer.com/wallet/HelixMixer-old5,helix
https://www.walletexplorer.com/wallet/HelixMixer-old6,helix
https://www.walletexplorer.com/wallet/HelixMixer-old7,helix
https://www.walletexplorer.com/wallet/HelixMixer-old8,helix
https://www.walletexplorer.com/wallet/HelixMixer-old9,helix
https://www.walletexplorer.com/wallet/HelixMixer-old10,helix
https://www.walletexplorer.com/wallet/HelixMixer-old11,helix
https://www.walletexplorer.com/wallet/HelixMixer-old12,helix
https://www.walletexplorer.com/wallet/HelixMixer-old13,helix
https://www.walletexplorer.com/wallet/HelixMixer-old14,helix
https://www.walletexplorer.com/wallet/HelixMixer-old15,helix
https://www.walletexplorer.com/wallet/HelixMixer-old16,helix
https://www.walletexplorer.com/wallet/HelixMixer-old17,helix
https://www.walletexplorer.com/wallet/HelixMixer-old18,helix
https://www.walletexplorer.com/wallet/HelixMixer-old19,helix
https://www.walletexplorer.com/wallet/HelixMixer-old20,helix
https://www.walletexplorer.com/wallet/HelixMixer-old21,helix
https://www.walletexplorer.com/wallet/HelixMixer-old22,helix
https://www.walletexplorer.com/wallet/HelixMixer-old23,helix
https://www.walletexplorer.com/wallet/HelixMixer-old24,helix
https://www.walletexplorer.com/wallet/HelixMixer-old25,helix
https://www.walletexplorer.com/wallet/HelixMixer-old26,helix
https://www.walletexplorer.com/wallet/HelixMixer-old27,helix
https://www.walletexplorer.com/wallet/HelixMixer-old28,helix
https://www.walletexplorer.com/wallet/HelixMixer-old29,helix
https://www.walletexplorer.com/wallet/HelixMixer-old30,helix
https://www.walletexplorer.com/wallet/HelixMixer-old31,helix
https://www.walletexplorer.com/wallet/ChBtc.com,chbtc.com
https://www.walletexplorer.com/wallet/Coins-e.com,coins-e.com
https://www.walletexplorer.com/wallet/LiteBit.eu,litebit.eu
https://www.walletexplorer.com/wallet/CoinCafe.com,coincafe.com
https://www.walletexplorer.com/wallet/UrduBit.com-cold,urdubit.com
https://www.walletexplorer.com/wallet/BTradeAustralia.com,btradeaustralia.com
https://www.walletexplorer.com/wallet/BTradeAustralia.com-incoming,btradeaustralia.com
https://www.walletexplorer.com/wallet/MeXBT.com,mexbt.com
https://www.walletexplorer.com/wallet/Coinomat.com,coinomat.com
https://www.walletexplorer.com/wallet/OrderBook.net,orderbook.net
https://www.walletexplorer.com/wallet/LakeBTC.com,lakebtc.com
https://www.walletexplorer.com/wallet/BitKonan.com,bitkonan.com
https://www.walletexplorer.com/wallet/QuadrigaCX.com,quadrigacx.com
https://www.walletexplorer.com/wallet/Banx.io,banx.io
https://www.walletexplorer.com/wallet/Banx.io-old,banx.io
https://www.walletexplorer.com/wallet/Banx.io-old2,banx.io
https://www.walletexplorer.com/wallet/CleverCoin.com,clevercoin.com
https://www.walletexplorer.com/wallet/Gatecoin.com,gatecoin.com
https://www.walletexplorer.com/wallet/Gatecoin.com-2,gatecoin.com
https://www.walletexplorer.com/wallet/Indacoin.com,indacoin.com
https://www.walletexplorer.com/wallet/CoinArch.com,coinarch.com
https://www.walletexplorer.com/wallet/BitcoinVietnam.com.vn,bitcoinvietnam.com.vn
https://www.walletexplorer.com/wallet/CoinChimp.com,coinchimp.com
https://www.walletexplorer.com/wallet/Cryptonit.net,cryptonit.net
https://www.walletexplorer.com/wallet/Cryptonit.net-old,cryptonit.net
https://www.walletexplorer.com/wallet/Coingi.com,coingi.com
https://www.walletexplorer.com/wallet/Exchange-Credit.ru,exchange-credit.ru
https://www.walletexplorer.com/wallet/Bitso.com,bitso.com
https://www.walletexplorer.com/wallet/Coinimal.com,coinimal.com
https://www.walletexplorer.com/wallet/EmpoEX.com,empoex.com
https://www.walletexplorer.com/wallet/Ccedk.com,ccedk.com
https://www.walletexplorer.com/wallet/UseCryptos.com,usecryptos.com
https://www.walletexplorer.com/wallet/BitcoinP2P.com.br,bitcoinp2p.com.br
https://www.walletexplorer.com/wallet/Coinbroker.io,coinbroker.io
''')

# %%
exchangeListDf = pd.read_csv(exchangeList,sep=",")

# %%
for index, row in exchangeListDf.iterrows():
    exchangeListDf.at[index, 'we-link'] = exchangeListDf['we-link'][index] + '/addresses'

# %% [markdown]
# ## set wallets of interest (unknown giant wallets)

# %%
giantWalletList = StringIO('''we-link,giant_wallet
https://www.walletexplorer.com/wallet/0000a19b8b6c6c59,unknown_large_wallet_01
https://www.walletexplorer.com/wallet/0000118f10f7db77,unknown_large_wallet_02
https://www.walletexplorer.com/wallet/0000011bd9c73aab/addresses,unknown_large_wallet_03
https://www.walletexplorer.com/wallet/000041c8c69fd054/addresses,unknown_large_wallet_04
''')

# %%
giantWalletListDf = pd.read_csv(giantWalletList,sep=",")

# %%
for index, row in giantWalletListDf.iterrows():
    giantWalletListDf.at[index, 'we-link'] = giantWalletListDf['we-link'][index] + '/addresses'

# %% [markdown]
# ## scrape all wallets of interests

# %%
def scrape(category, inputDf):
    p = 0
    for index, row in inputDf.iterrows():
        folder = category + "/" + str(p) + '_' + inputDf[category][index]
        p = p+1

        dir_save = folder
        print(dir_save)

        start_url = inputDf['we-link'][index]

        # make output directory
        try:
            os.mkdir('output/' + category)
        except:
            pass
                
        # create subdirectory for this wallet
        try:
            os.mkdir('output/{}'.format(dir_save), )
        except:
            pass
                
        # set current page to 0 or load from json file
        current_page = None
        try:
            with open('output/{}/current_page.json'.format(dir_save)) as json_file:
                current_page = json.load(json_file)
                print("start_with_current_page:",current_page)
        except:
            current_page = 0
            print("start_with_current_page:",current_page)	

        # get how many pages to scrape
        try:
            result = requests.get(start_url)
            doc = BeautifulSoup(result.text, "html.parser")
            page_tag = doc.find(text=re.compile("Page 1 /*")) #can add more attributes
            pages = int(page_tag.split('/')[1].strip())
        except:
            errorWait = randint(120,180)
            print('Disconnected on getting page amount. Continue in ' + str(errorWait) + ' seconds.')
            sleep(errorWait)
            
            result = requests.get(start_url)
            doc = BeautifulSoup(result.text, "html.parser")
            page_tag = doc.find(text=re.compile("Page 1 /*")) #can add more attributes
            pages = int(page_tag.split('/')[1].strip())         

        # loop over all pages and save addresses
        scraped_addresses = []

        # set sleeptimer to avoid disconnection by walletexplorer
        sleeptimerReset = 95
        sleeptimer = sleeptimerReset

        # loop
        for i in range(pages):
                    
            #  get scraped addresses to continue scraping
            if i < current_page:
                print('pass page', i)
                continue
                    
            try:
                with open('output/{}/scraped_addresses.json'.format(dir_save)) as f1:
                    scraped_addresses = json.load(f1)
            except:
                pass

            # make backup every 100 pages
            if i%100 == 0:
                try:
                    with open('output/{}/scraped_addresses.json'.format(dir_save)) as fb:
                        scraped_addresses_backup = json.load(fb)
                    with open('output/{}/scraped_addresses_backup.json'.format(dir_save), 'w') as fbb:
                        scraped_addresses_backup.extend('{Last page: '+str(i)+'}')
                        json.dump(scraped_addresses_backup, fbb)        
                except:
                    pass

            sleeptimer = sleeptimer-1
                    
            print(i,'/',pages)
                    
            if i == 0:
                url = start_url
            else:
                url = start_url + '?page='+str(i+1)
                    
            try: 
                result = requests.get(url)
                doc = BeautifulSoup(result.text, "html.parser")
                
                # get addresses with regex
                addresses = doc.find_all(text=re.compile("^(bc1|[13])[a-zA-HJ-NP-Z0-9]{25,39}$") )
                print('found', len(addresses), 'addresses in:', url)
                scraped_addresses.extend(addresses)
                sleep(1)

                if len(addresses) == 0 and i < (pages-1):
                    raise Exception('')
            except:
                errorWait = randint(120,180)
                print('Disconnected on getting addresses. Continue in ' + str(errorWait) + ' seconds.')
                sleep(errorWait)
                
                result = requests.get(url)
                doc = BeautifulSoup(result.text, "html.parser")

                # get addresses with regex
                addresses = doc.find_all(text=re.compile("^(bc1|[13])[a-zA-HJ-NP-Z0-9]{25,39}$") )
                print('found', len(addresses), 'addresses in:', url)
                scraped_addresses.extend(addresses)
                sleep(1)

            # stop if no addresses found
            if len(addresses) == 0:
                print('no addresses found in:', url)
                break
                    
            # print output to file
            with open('output/{}/scraped_addresses.json'.format(dir_save), 'w') as f:
                json.dump(scraped_addresses, f)
                sleep(1)

            # save current page
            current_page = current_page+1
            with open('output/{}/current_page.json'.format(dir_save), 'w') as outfile:
                json.dump(current_page, outfile)

            # adjust this to specify seconds to sleep
            if sleeptimer > 0:
                print('remaining pages until break: '+ str(sleeptimer))
                sleep(randint(1,2))
            else:
                print('remaining pages until break: '+ str(sleeptimer))
                sleeptimer = sleeptimerReset
                pauseWait=randint(60,120)
                print('Waiting. Continue in ' + str(pauseWait) + ' seconds.')
                sleep(pauseWait)

# %% [markdown]
# # EXECUTE: iterative scaping of websites for wallets of interest

# %%
# scrape('mixer', mixerListDf)

# %%
scrape('exchange', exchangeListDf)
# Out:
# exchange/0_huobi.com
# start_with_current_page: 293
# pass page 0
# pass page 1
# pass page 2
# pass page 3
# pass page 4
# pass page 5
# pass page 6
# pass page 7
# pass page 8
# pass page 9
# pass page 10
# pass page 11
# pass page 12
# pass page 13
# pass page 14
# pass page 15
# pass page 16
# pass page 17
# pass page 18
# pass page 19
# pass page 20
# pass page 21
# pass page 22
# pass page 23
# pass page 24
# pass page 25
# pass page 26
# pass page 27
# pass page 28
# pass page 29
# pass page 30
# pass page 31
# pass page 32
# pass page 33
# pass page 34
# pass page 35
# pass page 36
# pass page 37
# pass page 38
# pass page 39
# pass page 40
# pass page 41
# pass page 42
# pass page 43
# pass page 44
# pass page 45
# pass page 46
# pass page 47
# pass page 48
# pass page 49
# pass page 50
# pass page 51
# pass page 52
# pass page 53
# pass page 54
# pass page 55
# pass page 56
# pass page 57
# pass page 58
# pass page 59
# pass page 60
# pass page 61
# pass page 62
# pass page 63
# pass page 64
# pass page 65
# pass page 66
# pass page 67
# pass page 68
# pass page 69
# pass page 70
# pass page 71
# pass page 72
# pass page 73
# pass page 74
# pass page 75
# pass page 76
# pass page 77
# pass page 78
# pass page 79
# pass page 80
# pass page 81
# pass page 82
# pass page 83
# pass page 84
# pass page 85
# pass page 86
# pass page 87
# pass page 88
# pass page 89
# pass page 90
# pass page 91
# pass page 92
# pass page 93
# pass page 94
# pass page 95
# pass page 96
# pass page 97
# pass page 98
# pass page 99
# pass page 100
# pass page 101
# pass page 102
# pass page 103
# pass page 104
# pass page 105
# pass page 106
# pass page 107
# pass page 108
# pass page 109
# pass page 110
# pass page 111
# pass page 112
# pass page 113
# pass page 114
# pass page 115
# pass page 116
# pass page 117
# pass page 118
# pass page 119
# pass page 120
# pass page 121
# pass page 122
# pass page 123
# pass page 124
# pass page 125
# pass page 126
# pass page 127
# pass page 128
# pass page 129
# pass page 130
# pass page 131
# pass page 132
# pass page 133
# pass page 134
# pass page 135
# pass page 136
# pass page 137
# pass page 138
# pass page 139
# pass page 140
# pass page 141
# pass page 142
# pass page 143
# pass page 144
# pass page 145
# pass page 146
# pass page 147
# pass page 148
# pass page 149
# pass page 150
# pass page 151
# pass page 152
# pass page 153
# pass page 154
# pass page 155
# pass page 156
# pass page 157
# pass page 158
# pass page 159
# pass page 160
# pass page 161
# pass page 162
# pass page 163
# pass page 164
# pass page 165
# pass page 2937
# pass page 2938
# pass page 2939
# pass page 2940
# pass page 2941
# pass page 2942
# pass page 2943
# pass page 2944
# pass page 2945
# pass page 2946
# pass page 2947
# pass page 2948
# pass page 2949
# pass page 2950
# pass page 2951
# pass page 2952
# pass page 2953
# pass page 2954
# pass page 2955
# pass page 2956
# pass page 2957
# pass page 2958
# pass page 2959
# pass page 2960
# pass page 2961
# pass page 2962
# pass page 2963
# pass page 2964
# pass page 2965
# pass page 2966
# pass page 2967
# pass page 2968
# pass page 2969
# pass page 2970
# pass page 2971
# pass page 2972
# pass page 2973
# pass page 2974
# pass page 2975
# pass page 2976
# pass page 2977
# pass page 2978
# pass page 2979
# pass page 2980
# pass page 2981
# pass page 2982
# pass page 2983
# pass page 2984
# pass page 2985
# pass page 2986
# pass page 2987
# pass page 2988
# pass page 2989
# pass page 2990
# pass page 2991
# pass page 2992
# pass page 2993
# pass page 2994
# pass page 2995
# pass page 2996
# pass page 2997
# pass page 2998
# pass page 2999
# pass page 3000
# ...
#     359     hostname = self.host
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000249AAFCE290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.walletexplorer.com', port=443): Max retries exceeded with url: /wallet/Bittrex.com/addresses?page=9514 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000249AAFCE290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# x:\OneDrive\Dokumente\01_Bildung\02_Studium\04_Universitaet Mannheim\03_Semester_2\05_Team Project\02_Repo\UM_Cryptocurrency_Forensics\WalletExplorerScraper\Extract_addresses.ipynb Cell 26' in scrape(category, inputDf)
#      <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=90'>91</a> try:
# ---> <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=91'>92</a>     result = requests.get(url)
#      <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=92'>93</a>     doc = BeautifulSoup(result.text, "html.parser")
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.walletexplorer.com', port=443): Max retries exceeded with url: /wallet/Bittrex.com/addresses?page=9514 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000249AAFCE290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000249AAFCEBC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.walletexplorer.com', port=443): Max retries exceeded with url: /wallet/Bittrex.com/addresses?page=9514 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000249AAFCEBC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# x:\OneDrive\Dokumente\01_Bildung\02_Studium\04_Universitaet Mannheim\03_Semester_2\05_Team Project\02_Repo\UM_Cryptocurrency_Forensics\WalletExplorerScraper\Extract_addresses.ipynb Cell 29' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000028?line=0'>1</a> scrape('exchange', exchangeListDf)
#
# x:\OneDrive\Dokumente\01_Bildung\02_Studium\04_Universitaet Mannheim\03_Semester_2\05_Team Project\02_Repo\UM_Cryptocurrency_Forensics\WalletExplorerScraper\Extract_addresses.ipynb Cell 26' in scrape(category, inputDf)
#     <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=104'>105</a> print('Disconnected on getting addresses. Continue in ' + str(errorWait) + ' seconds.')
#     <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=105'>106</a> sleep(errorWait)
# --> <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=107'>108</a> result = requests.get(url)
#     <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=108'>109</a> doc = BeautifulSoup(result.text, "html.parser")
#     <a href='vscode-notebook-cell:/x%3A/OneDrive/Dokumente/01_Bildung/02_Studium/04_Universitaet%20Mannheim/03_Semester_2/05_Team%20Project/02_Repo/UM_Cryptocurrency_Forensics/WalletExplorerScraper/Extract_addresses.ipynb#ch0000025?line=110'>111</a> # get addresses with regex
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\info\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.walletexplorer.com', port=443): Max retries exceeded with url: /wallet/Bittrex.com/addresses?page=9514 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000249AAFCEBC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
scrape('giant_wallet', giantWalletListDf)

# %% [markdown]
# # [OLD] Start scraping for multible websites (old2. old3, old3 etc.)

# %% [markdown]
# Now already part of iterative scraping above.

# %%
# for i_old in range(35): # last is old34 mixer

#     if i_old < 2:
#         print('pass')
#         continue
    

#     dir_save = 'old'+str(i_old)
#     print(dir_save)

#     # dir_save = 'old'
#     start_url = 'https://www.walletexplorer.com/wallet/HelixMixer{}/addresses'.format('-'+dir_save)

#     # https://www.walletexplorer.com/wallet/HelixMixer/addresses
#     # https://www.walletexplorer.com/wallet/HelixMixer-old/addresses
#     # https://www.walletexplorer.com/wallet/HelixMixer-old2/addresses

#     try:
#         os.mkdir('{}'.format(dir_save), )
#     except:
#         pass

    

#     # get how many pages to scrape

#     result = requests.get(start_url)
#     doc = BeautifulSoup(result.text, "html.parser")

#     page_tag = doc.find(text=re.compile("Page 1 /*") ) #can add more attributes
#     pages = int(page_tag.split('/')[1].strip())




#     scraped_addresses = []

#     for i in range(pages):
#         if i == 0:
#             url = start_url
#         else:
#             url = start_url + '?page='+str(i+1)

#         result = requests.get(url)

#         doc = BeautifulSoup(result.text, "html.parser")

#         addresses = doc.find_all(text=re.compile("^(bc1|[13])[a-zA-HJ-NP-Z0-9]{25,39}$") )
#         print('found', len(addresses), 'addresses', url)
#         scraped_addresses.append(addresses)

#         sleep(randint(1,5))

#     flat_scraped_addresses = [x for xs in scraped_addresses for x in xs]
#     print(len(flat_scraped_addresses))

#     import json
#     with open('{}/scraped_addresses.json'.format(dir_save), 'w') as f:
#         json.dump(flat_scraped_addresses, f)
